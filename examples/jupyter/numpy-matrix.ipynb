# %%
import numpy as np

# %%
l1 = [[1,2,3],[4,5,6]]

# %%
l1
# Out:
# [[1, 2, 3], [4, 5, 6]]

# %%
m1=np.matrix(l1)

# %%
m1
# Out:
# matrix([[1, 2, 3],
#         [4, 5, 6]])

# %%
m2=np.matrix([[1,2],[3,4],[5,6]])

# %%
m2
# Out:
# matrix([[1, 2],
#         [3, 4],
#         [5, 6]])

# %%
m1*m2
# Out:
# matrix([[22, 28],
#         [49, 64]])

# %%
np.shape(m1)
# Out:
# (2, 3)

# %%
np.shape(m2)
# Out:
# (3, 2)

# %%
a1 = m1.A

# %%
a1
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
a2 = np.array([[1,2,3],[1,2,3]])

# %%
a2
# Out:
# array([[1, 2, 3],
#        [1, 2, 3]])

# %%
a1*a2
# Out:
# array([[ 1,  4,  9],
#        [ 4, 10, 18]])
