# %%
# %matplotlib notebook

# %%
import matplotlib.pylab as plt
import numpy as np

# %%
x = np.linspace(0,10)
line, = plt.plot(x, np.sin(x), '--', linewidth=2)
# Out:
# <img src="data:image/png;base64,...">
