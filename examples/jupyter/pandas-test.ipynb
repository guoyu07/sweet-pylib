# %%
obj = Series([4,7,-5,3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1496f58cea77> in <module>()
# ----> 1 obj = Series([4,7,-5,3])
#
# NameError: name 'Series' is not defined

# %%
from pandas import Series, DataFrame
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-4cbc956c4f0e> in <module>()
# ----> 1 from pandas import Series, DataFrame
#
# ImportError: No module named pandas

# %%
from pandas import Series, DataFrame

# %%
df1 = DataFrame({'key':['b','b','a','c','a','a','b'], 'data1':range(7)})

# %%
df1
# Out:
#    data1 key
# 0      0   b
# 1      1   b
# 2      2   a
# 3      3   c
# 4      4   a
# 5      5   a
# 6      6   b

# %%
df2 = DataFrame({'key':['a','b','d'],'data2':range(3)})

# %%
df2
# Out:
#    data2 key
# 0      0   a
# 1      1   b
# 2      2   d

# %%
pd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-6068f4b5ff32> in <module>()
# ----> 1 pd
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
pd
# Out:
# <module 'pandas' from '/usr/local/lib/python2.7/site-packages/pandas/__init__.pyc'>

# %%
pd.merge(df1, df2)
# Out:
#    data1 key  data2
# 0      0   b      1
# 1      1   b      1
# 2      6   b      1
# 3      2   a      0
# 4      4   a      0
# 5      5   a      0

# %%
pd.merge(df1, df2, how='outer')
# Out:
#    data1 key  data2
# 0    0.0   b    1.0
# 1    1.0   b    1.0
# 2    6.0   b    1.0
# 3    2.0   a    0.0
# 4    4.0   a    0.0
# 5    5.0   a    0.0
# 6    3.0   c    NaN
# 7    NaN   d    2.0

# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,...">

# %%
ax1 = fig.add_subplot(2,2,1)

# %%
ax2 = fig.add_subplot(2,2,2)

# %%
ax3 = fig.add_subplot(2,2,3)

# %%
from numpy.random import randn

# %%
plt.plot(randn(50).cumsum(), 'k--')

# %%
plt.plot(randn(50).cumsum(), 'k--')

# %%
ax1.hist(randn(100), bins=20, color='k',alpha=0.3)
# Out:
# (array([  1.,   0.,   0.,   2.,   3.,   5.,   8.,  11.,  13.,   9.,   6.,
#           9.,   6.,   5.,   9.,   1.,   5.,   4.,   1.,   2.]),
#  array([-2.961281  , -2.69064291, -2.42000482, -2.14936672, -1.87872863,
#         -1.60809053, -1.33745244, -1.06681434, -0.79617625, -0.52553815,
#         -0.25490006,  0.01573804,  0.28637613,  0.55701423,  0.82765232,
#          1.09829041,  1.36892851,  1.6395666 ,  1.9102047 ,  2.18084279,
#          2.45148089]),
#  <a list of 20 Patch objects>)

# %%
ax2.scatter(np.arange(30), np.arange(30)+3*randn(30))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-18c2553e41e6> in <module>()
# ----> 1 ax2.scatter(np.arange(30), np.arange(30)+3*randn(30))
#
# NameError: name 'np' is not defined

# %%
import numpy as np

# %%
ax2.scatter(np.arange(30), np.arange(30)+3*randn(30))
